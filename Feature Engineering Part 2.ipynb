# %% [markdown]
# ###**Handling Categorical Feature**

# %% [markdown]
# ###Ordinal Number Encoding

# %%
import datetime

# %%
today_date=datetime.datetime.today()

# %%
today_date
# Out:
# datetime.datetime(2020, 12, 7, 17, 7, 26, 398461)

# %%
today_date-datetime.timedelta(3)
# Out:
# datetime.datetime(2020, 12, 4, 17, 7, 26, 398461)

# %%
####List Comprehension
days=[today_date-datetime.timedelta(x) for x in range(0,15)]

# %%
import pandas as pd
data=pd.DataFrame(days)
data.columns=['Day']

# %%
data.head()
# Out:
#                          Day
# 0 2020-12-07 17:07:26.398461
# 1 2020-12-06 17:07:26.398461
# 2 2020-12-05 17:07:26.398461
# 3 2020-12-04 17:07:26.398461
# 4 2020-12-03 17:07:26.398461

# %%
data['weekday']=data['Day'].dt.day_name()
data.head()
# Out:
#                          Day   weekday
# 0 2020-12-07 17:07:26.398461    Monday
# 1 2020-12-06 17:07:26.398461    Sunday
# 2 2020-12-05 17:07:26.398461  Saturday
# 3 2020-12-04 17:07:26.398461    Friday
# 4 2020-12-03 17:07:26.398461  Thursday

# %%
dictionary={'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7}
dictionary
# Out:
# {'Friday': 5,
#  'Monday': 1,
#  'Saturday': 6,
#  'Sunday': 7,
#  'Thursday': 4,
#  'Tuesday': 2,
#  'Wednesday': 3}

# %%
data['weekday'].map(dictionary)
# Out:
# 0     1
# 1     7
# 2     6
# 3     5
# 4     4
# 5     3
# 6     2
# 7     1
# 8     7
# 9     6
# 10    5
# 11    4
# 12    3
# 13    2
# 14    1
# Name: weekday, dtype: int64

# %%
data['weekday_ordinal']=data['weekday'].map(dictionary)

# %%
data
# Out:
#                           Day    weekday  weekday_ordinal
# 0  2020-12-07 17:07:26.398461     Monday                1
# 1  2020-12-06 17:07:26.398461     Sunday                7
# 2  2020-12-05 17:07:26.398461   Saturday                6
# 3  2020-12-04 17:07:26.398461     Friday                5
# 4  2020-12-03 17:07:26.398461   Thursday                4
# 5  2020-12-02 17:07:26.398461  Wednesday                3
# 6  2020-12-01 17:07:26.398461    Tuesday                2
# 7  2020-11-30 17:07:26.398461     Monday                1
# 8  2020-11-29 17:07:26.398461     Sunday                7
# 9  2020-11-28 17:07:26.398461   Saturday                6
# 10 2020-11-27 17:07:26.398461     Friday                5
# 11 2020-11-26 17:07:26.398461   Thursday                4
# 12 2020-11-25 17:07:26.398461  Wednesday                3
# 13 2020-11-24 17:07:26.398461    Tuesday                2
# 14 2020-11-23 17:07:26.398461     Monday                1

# %% [markdown]
# ####Count or Frequency Encoding

# %%
train_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data' , header = None,index_col=None)
train_set.head()
# Out:
#    0                  1       2           3   ...  11  12              13      14
# 0  39          State-gov   77516   Bachelors  ...   0  40   United-States   <=50K
# 1  50   Self-emp-not-inc   83311   Bachelors  ...   0  13   United-States   <=50K
# 2  38            Private  215646     HS-grad  ...   0  40   United-States   <=50K
# 3  53            Private  234721        11th  ...   0  40   United-States   <=50K
# 4  28            Private  338409   Bachelors  ...   0  40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
train_set[1].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
columns=[1,3,5,6,7,8,9,13]

# %%
train_set=train_set[columns]

# %%
train_set.columns=['Employment','Degree','Status','Designation','family_job','Race','Sex','Country']

# %%
train_set.head()
# Out:
#           Employment      Degree  ...      Sex         Country
# 0          State-gov   Bachelors  ...     Male   United-States
# 1   Self-emp-not-inc   Bachelors  ...     Male   United-States
# 2            Private     HS-grad  ...     Male   United-States
# 3            Private        11th  ...     Male   United-States
# 4            Private   Bachelors  ...   Female            Cuba
#
# [5 rows x 8 columns]

# %%
for feature in train_set.columns[:]:
    print(feature,":",len(train_set[feature].unique()),'labels')
# Out:
# Employment : 9 labels
# Degree : 16 labels
# Status : 7 labels
# Designation : 15 labels
# family_job : 6 labels
# Race : 5 labels
# Sex : 2 labels
# Country : 42 labels

# %%
train_set['Country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  Greece                           29
#  France                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Thailand                         18
#  Laos                             18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Country, dtype: int64

# %%
country_map=train_set['Country'].value_counts().to_dict()

# %%
train_set['Country']=train_set['Country'].map(country_map)
train_set.head(20)
# Out:
#            Employment         Degree  ...      Sex Country
# 0           State-gov      Bachelors  ...     Male   29170
# 1    Self-emp-not-inc      Bachelors  ...     Male   29170
# 2             Private        HS-grad  ...     Male   29170
# 3             Private           11th  ...     Male   29170
# 4             Private      Bachelors  ...   Female      95
# 5             Private        Masters  ...   Female   29170
# 6             Private            9th  ...   Female      81
# 7    Self-emp-not-inc        HS-grad  ...     Male   29170
# 8             Private        Masters  ...   Female   29170
# 9             Private      Bachelors  ...     Male   29170
# 10            Private   Some-college  ...     Male   29170
# 11          State-gov      Bachelors  ...     Male     100
# 12            Private      Bachelors  ...   Female   29170
# 13            Private     Assoc-acdm  ...     Male   29170
# 14            Private      Assoc-voc  ...     Male     583
# 15            Private        7th-8th  ...     Male     643
# 16   Self-emp-not-inc        HS-grad  ...     Male   29170
# 17            Private        HS-grad  ...     Male   29170
# 18            Private           11th  ...     Male   29170
# 19   Self-emp-not-inc        Masters  ...   Female   29170
#
# [20 rows x 8 columns]

# %% [markdown]
# #### Advantages
# 1. Easy To Use
# 2. Not increasing feature space
#
# ##### Disadvantages
# 1. It will provide same weight if the frequencies are same

# %% [markdown]
# ####Target Guided Ordinal Encoding
# 1. Ordering the labels according to the target
# 2. Replace the labels by the joint probability of being 1 or 0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv('/content/gdrive/My Drive/titanic.csv', usecols=['Cabin','Survived'])
df.head()
# Out:
#    Survived Cabin
# 0         0   NaN
# 1         1   C85
# 2         1   NaN
# 3         1  C123
# 4         0   NaN

# %%
df['Cabin'].fillna('Missing',inplace=True)

# %%
df['Cabin']=df['Cabin'].astype(str).str[0]

# %%
df.head()
# Out:
#    Survived Cabin
# 0         0     M
# 1         1     C
# 2         1     M
# 3         1     C
# 4         0     M

# %%
df.Cabin.unique()
# Out:
# array(['M', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
df.groupby(['Cabin'])['Survived'].mean()
# Out:
# Cabin
# A    0.466667
# B    0.744681
# C    0.593220
# D    0.757576
# E    0.750000
# F    0.615385
# G    0.500000
# M    0.299854
# T    0.000000
# Name: Survived, dtype: float64

# %%
df.groupby(['Cabin'])['Survived'].mean().sort_values().index
# Out:
# Index(['T', 'M', 'A', 'G', 'C', 'F', 'B', 'E', 'D'], dtype='object', name='Cabin')

# %%
ordinal_labels=df.groupby(['Cabin'])['Survived'].mean().sort_values().index
ordinal_labels
# Out:
# Index(['T', 'M', 'A', 'G', 'C', 'F', 'B', 'E', 'D'], dtype='object', name='Cabin')

# %%
enumerate(ordinal_labels,0)

# %%
ordinal_labels2={k:i for i,k in enumerate(ordinal_labels,0)}
ordinal_labels2
# Out:
# {'A': 2, 'B': 6, 'C': 4, 'D': 8, 'E': 7, 'F': 5, 'G': 3, 'M': 1, 'T': 0}

# %%
df['Cabin_ordinal_labels']=df['Cabin'].map(ordinal_labels2)
df.head()
# Out:
#    Survived Cabin  Cabin_ordinal_labels
# 0         0     M                     1
# 1         1     C                     4
# 2         1     M                     1
# 3         1     C                     4
# 4         0     M                     1

# %% [markdown]
# ####Mean Encoding

# %%
mean_ordinal=df.groupby(['Cabin'])['Survived'].mean().to_dict()

# %%
mean_ordinal
# Out:
# {'A': 0.4666666666666667,
#  'B': 0.7446808510638298,
#  'C': 0.5932203389830508,
#  'D': 0.7575757575757576,
#  'E': 0.75,
#  'F': 0.6153846153846154,
#  'G': 0.5,
#  'M': 0.29985443959243085,
#  'T': 0.0}

# %%
df['mean_ordinal_encode']=df['Cabin'].map(mean_ordinal)
df.head()
# Out:
#    Survived Cabin  Cabin_ordinal_labels  mean_ordinal_encode
# 0         0     M                     1             0.299854
# 1         1     C                     4             0.593220
# 2         1     M                     1             0.299854
# 3         1     C                     4             0.593220
# 4         0     M                     1             0.299854

# %% [markdown]
# #### Advantages
# 1. It captures information within the label therefore rendering more predictive features.
# 2. It creates a monotonic relationship between variable and the target.
#
# #### Disadvantages
# 1. Prone to overfitting
